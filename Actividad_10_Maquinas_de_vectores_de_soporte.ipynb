# %% [markdown]
# Vamos a utilizar un base de datos de cancer de mama y lo importaremos con sklearn. Usaremos (as_frame=True) para que nos pueda hacer un dataframe

# %%
from sklearn import datasets

datos = datasets.load_breast_cancer(as_frame=True)

# %% [markdown]
# Vemos los datos

# %%
datos.frame.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# ...

# %% [markdown]
# Tambien podemos usar esto para ver mas información

# %%
datos.frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   mean radius              569 non-null    float64
#  1   mean texture             569 non-null    float64
#  2   mean perimeter           569 non-null    float64
#  3   mean area                569 non-null    float64
#  4   mean smoothness          569 non-null    float64
#  5   mean compactness         569 non-null    float64
#  6   mean concavity           569 non-null    float64
#  7   mean concave points      569 non-null    float64
#  8   mean symmetry            569 non-null    float64
#  9   mean fractal dimension   569 non-null    float64
#  10  radius error             569 non-null    float64
#  11  texture error            569 non-null    float64
#  12  perimeter error          569 non-null    float64
# ...

# %% [markdown]
# Y como podemos ver no hay datos vacios

# %% [markdown]
# Y lo podemos confirmar

# %%
datos.frame.isna(). sum()
# Out:
# mean radius                0
# mean texture               0
# mean perimeter             0
# mean area                  0
# mean smoothness            0
# mean compactness           0
# mean concavity             0
# mean concave points        0
# mean symmetry              0
# mean fractal dimension     0
# radius error               0
# texture error              0
# perimeter error            0
# area error                 0
# smoothness error           0
# compactness error          0
# concavity error            0
# concave points error       0
# symmetry error             0
# fractal dimension error    0
# worst radius               0
# worst texture              0
# worst perimeter            0
# worst area                 0
# worst smoothness           0
# worst compactness          0
# worst concavity            0
# worst concave points       0
# worst symmetry             0
# worst fractal dimension    0
# target                     0
# dtype: int64

# %% [markdown]
# O podemos usar (datos.frame.describe()) para obtener los datos de mejor manera

# %%
datos.frame.describe()
# Out:
#        mean radius  mean texture  mean perimeter    mean area  \
# count   569.000000    569.000000      569.000000   569.000000
# mean     14.127292     19.289649       91.969033   654.889104
# std       3.524049      4.301036       24.298981   351.914129
# min       6.981000      9.710000       43.790000   143.500000
# 25%      11.700000     16.170000       75.170000   420.300000
# 50%      13.370000     18.840000       86.240000   551.100000
# 75%      15.780000     21.800000      104.100000   782.700000
# max      28.110000     39.280000      188.500000  2501.000000
#
#        mean smoothness  mean compactness  mean concavity  mean concave points  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# std           0.014064          0.052813        0.079720             0.038803
# min           0.052630          0.019380        0.000000             0.000000
# ...

# %% [markdown]
# Usaremos datos.data.shape para ver la forma que tienen los datos

# %%
datos.data.shape
# Out:
# (569, 30)

# %% [markdown]
# Son 569 registros con 30 caracteristicas

# %% [markdown]
# Ahora crearemos el modelo para hacer las predicciones

# %%
from sklearn.model_selection import train_test_split

X = datos.data
y = datos.target

X_ent, X_pru, y_ent, y_pru = train_test_split(X, y, test_size= .3)

# %%
from sklearn import svm
from sklearn import metrics

modelo = svm.SVC()
modelo.fit(X_ent, y_ent)
predicciones = modelo.predict(X_pru)
print("Exactitud:", metrics.accuracy_score(y_pru, predicciones))
print("Precisión:", metrics.precision_score(y_pru, predicciones))
# Out:
# Exactitud: 0.9064327485380117
# Precisión: 0.8728813559322034

# %% [markdown]
# Haremos una lista de los diferentes kernels que podemos usar y tambien podemos usar diferentes valores de gamma

# %%
from sklearn import svm
from sklearn import metrics

kernels = ["linear", "rbf", "sigmoid"] # Changed 'Linear' to 'linear'
gamma = [1, .01, .001, .0001, .00001]

for kernel in kernels:
  for gamma_val in gamma:
    modelo = svm.SVC(kernel=kernel, gamma=gamma_val)
    modelo.fit(X_ent, y_ent)
    predicciones = modelo.predict(X_pru)
    print(f"{kernel}: Gamma: {gamma_val}: Exactitud:", metrics.accuracy_score(y_pru, predicciones))
    print(f"{kernel}: Gamma: {gamma_val}: Precisión:", metrics.precision_score(y_pru, predicciones))
# Out:
# linear: Gamma: 1: Exactitud: 0.935672514619883
# linear: Gamma: 1: Precisión: 0.9043478260869565
# linear: Gamma: 0.01: Exactitud: 0.935672514619883
# linear: Gamma: 0.01: Precisión: 0.9043478260869565
# linear: Gamma: 0.001: Exactitud: 0.935672514619883
# linear: Gamma: 0.001: Precisión: 0.9043478260869565
# linear: Gamma: 0.0001: Exactitud: 0.935672514619883
# linear: Gamma: 0.0001: Precisión: 0.9043478260869565
# linear: Gamma: 1e-05: Exactitud: 0.935672514619883
# linear: Gamma: 1e-05: Precisión: 0.9043478260869565
# rbf: Gamma: 1: Exactitud: 0.6081871345029239
# rbf: Gamma: 1: Precisión: 0.6081871345029239
# rbf: Gamma: 0.01: Exactitud: 0.6081871345029239
# rbf: Gamma: 0.01: Precisión: 0.6081871345029239
# rbf: Gamma: 0.001: Exactitud: 0.9239766081871345
# rbf: Gamma: 0.001: Precisión: 0.9174311926605505
# rbf: Gamma: 0.0001: Exactitud: 0.9239766081871345
# rbf: Gamma: 0.0001: Precisión: 0.9099099099099099
# rbf: Gamma: 1e-05: Exactitud: 0.9064327485380117
# ...

# %% [markdown]
# Ahora especificaremos que el kernel sea linear

# %%
modelo = svm.SVC(kernel="linear")
modelo.fit(X_ent, y_ent)
predicciones = modelo.predict(X_pru)
print(f"{kernel}: Gamma: {gamma_val}: Exactitud:", metrics.accuracy_score(y_pru, predicciones))
print(f"{kernel}: Gamma: {gamma_val}: Precisión:", metrics.precision_score(y_pru, predicciones))
# Out:
# sigmoid: Gamma: 1e-05: Exactitud: 0.935672514619883
# sigmoid: Gamma: 1e-05: Precisión: 0.9043478260869565

# %% [markdown]
# Y hacemos el reporte de calificaciones

# %%
from sklearn.metrics import classification_report

print(classification_report(y_pru, predicciones))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.84      0.91        67
#            1       0.90      1.00      0.95       104
#
#     accuracy                           0.94       171
#    macro avg       0.95      0.92      0.93       171
# weighted avg       0.94      0.94      0.93       171

# %% [markdown]
# Y ya por ultimo lo metemos en un DataFrame

# %%
from sklearn.metrics import confusion_matrix
import pandas as pd

pd.DataFrame(confusion_matrix(y_pru, predicciones))
# Out:
#     0    1
# 0  56   11
# 1   0  104
